# %% [markdown]
# <a href="https://colab.research.google.com/github/LeopoldoGitHub/InmersionAlura/blob/main/Copia_de_Inmersion_datos_aula1_aula2Leopoldo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bienvenido a mi primer encuentro de inmersion de datos

# %% [markdown]
# bienvenido a mi primer encuentro de inmersion de datos

# %% [markdown]
# # **AULA 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")

# %%
columnas={"Baños":"Banos","Área":"Area"}
inmuebles=inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6330  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 1583         Casa                Casa en venta en Teusaquillo             2
# 6678  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1828  Apartamento               Apartamento en venta en Marly             1
# 7845  Apartamento        Apartamento en venta en Gran Granada             3
# 8434  Apartamento       Apartamento en venta en Santa Barbara             3
# 2538  Apartamento       Apartamento en venta en Pinar De Suba             3
# 2487  Apartamento      Apartamento en venta en Barrios Unidos             3
# 1060  Apartamento            Apartamento en venta en Cedritos             4
# 8056  Apartamento             Apartamento en venta en Kennedy             3
#
#       Banos  Area              Barrio                                    UPZ  \
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles["Valor"][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles["Valor"][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles["Valor"][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles["Valor"][300])
# Out:
# str

# %%
type(inmuebles["Valor"][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                Descripcion  Habitaciones  \
# 4819  Apartamento      Apartamento en venta en Puente Aranda             2
# 2189  Apartamento            Apartamento en venta en Usaquén             2
# 8848  Apartamento  Apartamento en venta en Chapinero Central             1
# 6035  Apartamento           Apartamento en venta en Cedritos             3
# 2146         Casa             Casa en venta en San Cristobal             3
# ...           ...                                        ...           ...
# 7897  Apartamento      Apartamento en venta en Villa Alsacia             2
# 365   Apartamento       Apartamento en venta en Los Mártires             3
# 1587  Apartamento            Apartamento en venta en Usaquén             4
# 6140  Apartamento           Apartamento en venta en Villemar             2
# 2370  Apartamento        Apartamento en venta en Santa Paula             3
#
#       Banos  Area             Barrio  \
# ...

# %%
(inmuebles.Barrio=="Chico Reservado")
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio=="Chico Reservado"))
# Out:
# 225

# %%
inmuebles_chico=(inmuebles.Barrio=="Chico Reservado")
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico=inmuebles[inmuebles_chico]
chico
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado=inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio=inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # DESAFIO 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")

# %%
columnas={"Baños":"Banos","Área":"Area"}
inmuebles=inmuebles.rename(columns=columnas)

# %% [markdown]
# 1. promedio de área de todos los barrios y crear grafico con esos promedios(top ten)
# 2. consutar otros datos estadisticos: conteo , mediana, valor minimo y maximo

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.Area.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-ba8b81ee0225> in <module>
# ----> 1 inmuebles.Area.mean()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Area'

# %%
columnas={"Baños":"Banos","Área":"Area"}
inmuebles=inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 399   Apartamento    Apartamento en venta en Chapinero             2      2
# 2332  Apartamento         Apartamento en venta en Suba             3      2
# 5966  Apartamento      Apartamento en venta en Usaquén             4      3
# 7847  Apartamento         Apartamento en venta en Suba             3      2
# 1383  Apartamento      Apartamento en venta en Kennedy             3      2
# 1177        Local     Local en venta en Barrios Unidos            12      6
# 7990         Casa  Casa en venta en Rafael Uribe Uribe             7      3
# 151   Apartamento     Apartamento en venta en Cedritos             2      2
# 2315         Casa         Casa en venta en Teusaquillo            18      9
# 6206  Apartamento     Apartamento en venta en Cedritos             3      2
#
#       Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.Area.value_counts()
# Out:
# 47      260
# 60      174
# 48      172
# 54      168
# 70      151
#        ...
# 3500      1
# 414       1
# 251       1
# 1100      1
# 594       1
# Name: Area, Length: 478, dtype: int64

# %%
media_areas_barrios  =  inmuebles.groupby('Barrio')['Area'].mean()

media_areas_barrios
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
columnas={"Baños":"Banos","Área":"Area"}
inmuebles=inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 6022  Apartamento   Apartamento en venta en Santa Barbara             2
# 2342  Apartamento            Apartamento en venta en Suba             3
# 4306  Apartamento  Apartamento en venta en Barrios Unidos             3
# 4151  Apartamento            Apartamento en venta en Bosa             3
# 3276  Apartamento         Apartamento en venta en Usaquén             2
# 4985  Apartamento     Apartamento en venta en Los Rosales             3
# 501   Apartamento        Apartamento en venta en Fontibón             3
# 2314         Casa     Casa en venta en Zona Noroccidental            10
# 6697  Apartamento         Apartamento en venta en Usaquén             2
# 6305         Casa         Casa en venta en Barrios Unidos             3
#
#       Banos  Area              Barrio                                    UPZ  \
# 6022      2    62       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# ...

# %%
media_areas_barrios  =  inmuebles.groupby('Barrio')['Area'].mean()

media_areas_barrios
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
round(media_areas_barrios,1)
# Out:
# Barrio
# Alameda                97.0
# Alhambra              190.4
# Andes Norte           124.9
# Antonio Nariño        163.1
# Barrancas              70.2
#                       ...
# Villa Maria           207.2
# Villas De Granada      86.6
# Villemar               76.9
# Zona Franca            54.0
# Zona Noroccidental    135.8
# Name: Area, Length: 149, dtype: float64

# %%
media_areas_barrios.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
media_areas_barrios.head(10)
# Out:
# Barrio
# Alameda                   97.000000
# Alhambra                 190.411765
# Andes Norte              124.857143
# Antonio Nariño           163.062500
# Barrancas                 70.200000
# Barrios Unidos           185.621564
# Bella Suiza              119.067961
# Bellavista Occidental    286.200000
# Bochica                  134.250000
# Bogotá D.C               133.785714
# Name: Area, dtype: float64

# %%
sort(media_areas_barrios.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a22fa6ae2034> in <module>
# ----> 1 sort(media_areas_barrios.head(10))
#
# NameError: name 'sort' is not defined

# %%
media_areas_barrios.head(10).sort_values()
# Out:
# Barrio
# Barrancas                 70.200000
# Alameda                   97.000000
# Bella Suiza              119.067961
# Andes Norte              124.857143
# Bogotá D.C               133.785714
# Bochica                  134.250000
# Antonio Nariño           163.062500
# Barrios Unidos           185.621564
# Alhambra                 190.411765
# Bellavista Occidental    286.200000
# Name: Area, dtype: float64

# %%
media_areas_barrios.head(10).sort_values()
# Out:
# Barrio
# Barrancas                 70.200000
# Alameda                   97.000000
# Bella Suiza              119.067961
# Andes Norte              124.857143
# Bogotá D.C               133.785714
# Bochica                  134.250000
# Antonio Nariño           163.062500
# Barrios Unidos           185.621564
# Alhambra                 190.411765
# Bellavista Occidental    286.200000
# Name: Area, dtype: float64

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %%
columnas={"Área":"Area","Baños":"Banos"}
inmuebles=inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3162  Apartamento           Apartamento en venta en Chapinero             3
# 4570  Apartamento             Apartamento en venta en Usaquén             5
# 1756  Apartamento  Apartamento en venta en Rafael Uribe Uribe             2
# 6281         Casa                    Casa en venta en Usaquén             3
# 2938  Apartamento                Apartamento en venta en Bosa             3
# 5286  Apartamento                Apartamento en venta en Bosa             3
# 2375         Casa              Casa en venta en Chico Navarra             4
# 6673  Apartamento            Apartamento en venta en Hayuelos             3
# 4317         Casa                   Casa en venta en Engativa             3
# 1983         Casa                       Casa en venta en Suba             2
#
#       Banos  Area              Barrio                                    UPZ  \
# ...

# %%
media_areas_barrios  =  inmuebles.groupby("Barrio")["Area"].mean()
media_areas_barrios
# Out:
# Barrio
# Alameda               97.00
# Alhambra             190.41
# Andes Norte          124.86
# Antonio Nariño       163.06
# Barrancas             70.20
#                       ...
# Villa Maria          207.15
# Villas De Granada     86.59
# Villemar              76.89
# Zona Franca           54.00
# Zona Noroccidental   135.79
# Name: Area, Length: 149, dtype: float64

# %%
media_areas_barrios.sample(10)
# Out:
# Barrio
# Bellavista Occidental    286.200000
# Santa Ana                309.375000
# Boyaca                   193.357143
# Los Mártires             143.763158
# Timiza                   128.000000
# Nicolas De Federman      126.675676
# El Contador              123.240000
# Fontibón                  94.011111
# Santa Fe                 100.813187
# Ricaurte                 167.800000
# Name: Area, dtype: float64

# %%
media_areas_barrios.sample(10).sort_values()
# Out:
# Barrio
# Prado Veraniego     25.000000
# Las Cruces          45.000000
# Nueva Zelandia      73.733333
# Villemar            76.888889
# Usme                83.901961
# Gran America        95.833333
# Andes Norte        124.857143
# Teusaquillo        172.538889
# El Retiro          214.578947
# Las Delicias       276.333333
# Name: Area, dtype: float64

# %%
media_areas_barrios.head(10).sort_values()
# Out:
# Barrio
# Barrancas                 70.200000
# Alameda                   97.000000
# Bella Suiza              119.067961
# Andes Norte              124.857143
# Bogotá D.C               133.785714
# Bochica                  134.250000
# Antonio Nariño           163.062500
# Barrios Unidos           185.621564
# Alhambra                 190.411765
# Bellavista Occidental    286.200000
# Name: Area, dtype: float64

# %%
media_areas_barrios.nlargest(n=10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
round(media_areas_barrios.nlargest(n=10),1)
# Out:
# Barrio
# Modelia                  4316.8
# Libertador                642.0
# Bosa Piamonte             400.0
# La Soledad                378.6
# Restrepo                  336.5
# Santa Librada             328.0
# Las Ferias                320.0
# Santa Ana                 309.4
# Veraguas                  302.7
# Bellavista Occidental     286.2
# Name: Area, dtype: float64

# %%
round(media_areas_barrios.nlargest(n=10),1).plot.bar()#Desafío. EL promedio de áreas del top 10 de Barrios en este Dataframe.
# Out:
# <Axes: xlabel='Barrio'>

# %%
media_areas_barrios.value_counts()
# Out:
# 41.000000     2
# 80.000000     2
# 54.000000     2
# 134.250000    2
# 97.000000     1
#              ..
# 86.500000     1
# 89.322581     1
# 123.240000    1
# 182.191781    1
# 135.785633    1
# Name: Area, Length: 145, dtype: int64

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
media_areas_barrios.median()
# Out:
# 120.57142857142857

# %%
mediana_areas_barrios=inmuebles.groupby("Barrio")["Area"].median()
mediana_areas_barrios
# Out:
# Barrio
# Alameda                97.0
# Alhambra              164.0
# Andes Norte           108.0
# Antonio Nariño         72.0
# Barrancas              75.0
#                       ...
# Villa Maria           222.0
# Villas De Granada      64.0
# Villemar               59.0
# Zona Franca            54.0
# Zona Noroccidental     78.0
# Name: Area, Length: 149, dtype: float64

# %%
mediana_areas_barrios.nlargest(n=10)
# Out:
# Barrio
# Libertador       642.0
# Bosa Piamonte    400.0
# Restrepo         365.0
# Santa Librada    328.0
# Las Ferias       320.0
# Las Delicias     280.0
# Boyaca           278.0
# Roma             260.0
# Chico Navarra    259.0
# Santa Ana        245.0
# Name: Area, dtype: float64

# %%
mediana_areas_barrios.nlargest(n=10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
round(media_areas_barrios.nlargest(n=10),1)
# Out:
# Barrio
# Modelia                  4316.8
# Libertador                642.0
# Bosa Piamonte             400.0
# La Soledad                378.6
# Restrepo                  336.5
# Santa Librada             328.0
# Las Ferias                320.0
# Santa Ana                 309.4
# Veraguas                  302.7
# Bellavista Occidental     286.2
# Name: Area, dtype: float64

# %%
media_areas_barrios.max()
# Out:
# 4316.75

# %%
media_areas_barrios.min()
# Out:
# 25.0

# %%
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %%
inmuebles.sample(5)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2774  Apartamento  Apartamento en venta en Chico Reservado             2
# 8727  Apartamento          Apartamento en venta en Usaquén             3
# 8864         Casa             Casa en venta en Bella Suiza            14
# 1380  Apartamento          Apartamento en venta en El Plan             2
# 5665  Apartamento     Apartamento en venta en Los Mártires             3
#
#       Banos  Area           Barrio                                    UPZ  \
# 2774      2   114  Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 8727      2    62          Usaquén                                Usaquén
# 8864      6   811      Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 1380      2    73          El Plan                              El Rincón
# 5665      2    60     Los Mártires                              La Sabana
#
#                 Valor
# 2774    $ 749.999.999
# 8727    $ 220.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# # **AULA 2**

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[0:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
type(inmuebles.Valor.str.split(expand=True))
# Out:
# pandas.core.frame.DataFrame

# %%
valor=inmuebles.Valor.str.split(expand=True)
inmuebles["Moneda"]=valor[0]
inmuebles["Precio"]=valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8727  Apartamento        Apartamento en venta en Usaquén             3      2
# 3255  Apartamento        Apartamento en venta en Usaquén             4      5
# 3052  Apartamento  Apartamento en venta en Chico Navarra             2      3
#
#       Area         Barrio                                    UPZ  \
# 8727    62        Usaquén                                Usaquén
# 3255   402        Usaquén                                Usaquén
# 3052   125  Chico Navarra  USAQUÉN: Country Club + Santa Bárbara
#
#                 Valor Moneda         Precio
# 8727    $ 220.000.000      $    220.000.000
# 3255  $ 5.200.000.000      $  5.200.000.000
# 3052    $ 800.000.000      $    800.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles["Precio"].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
inmuebles["Precio"]=inmuebles["Precio"].str.replace(".","",regex=True)

# %%
inmuebles[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles["Precio_Millon"]=inmuebles.Precio.astype("float")/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format",lambda x: "%.2f" % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones==110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area==2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon")
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,2000)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon")
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon",kde=True)
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon",kde=True, hue="Tipo")
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,1000)
plt.savefig("/content/drive/MyDrive/InmersionDatos/distibucion_valor_inmuebles.png",format="png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon",kde=True, hue="Tipo")
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,1000)
plt.ylim(0,50)
plt.savefig("/content/drive/MyDrive/InmersionDatos/distibucion_valor_inmuebles.png",format="png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon",kde=True, hue="Tipo")
grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")
plt.xlim(50,1000)
plt.savefig("/content/drive/MyDrive/InmersionDatos/distibucion_valor_inmuebles.png",format="png")
plt.show()

# %% [markdown]
# # **DESAFIOS DIA 2**
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles(Refinar el gráfico:Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
# 2.Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
inmuebles=pd.read_csv("/content/drive/MyDrive/InmersionDatos/inmuebles.csv")

# %%
columnas={"Baños":"Banos","Área":"Area"}
inmuebles=inmuebles.rename(columns=columnas)

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor=inmuebles.Valor.str.split(expand=True)
inmuebles["Moneda"]=valor[0]
inmuebles["Precio"]=valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                           Descripcion  Habitaciones  Banos  \
# 7084  Apartamento  Apartamento en venta en San Patricio             3      2
# 7614  Apartamento     Apartamento en venta en Normandia             1      2
# 5341  Apartamento          Apartamento en venta en Bosa             2      1
#
#       Area        Barrio                                         UPZ  \
# 7084   104  San Patricio       USAQUÉN: Country Club + Santa Bárbara
# 7614    56     Normandia  ENGATIVÁ: Santa Cecilia + Jardín  Botánico
# 5341    47          Bosa                                Bosa Central
#
#               Valor Moneda       Precio
# 7084  $ 800.000.000      $  800.000.000
# 7614  $ 465.000.000      $  465.000.000
# 5341  $ 130.000.000      $  130.000.000

# %%
inmuebles["Precio"]=inmuebles["Precio"].str.replace(".","",regex=True)

# %%
inmuebles[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles["Precio_Millon"]=inmuebles.Precio.astype("float")/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format",lambda x: "%.2f" % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon
# ...

# %%
media_areas_barrios.nlargest(n=10)
# Out:
# Barrio
# Modelia                 4316.75
# Libertador               642.00
# Bosa Piamonte            400.00
# La Soledad               378.62
# Restrepo                 336.50
# Santa Librada            328.00
# Las Ferias               320.00
# Santa Ana                309.38
# Veraguas                 302.67
# Bellavista Occidental    286.20
# Name: Area, dtype: float64

# %%
inmuebles[["Barrio","Area","Precio_Millon"]]
# Out:
#                       Barrio  Area  Precio_Millon
# 0         Zona Noroccidental    70         360.00
# 1                   Castilla   170         670.00
# 2            Chico Reservado   144        1120.00
# 3                    Usaquén   154         890.00
# 4                Bella Suiza   128         970.00
# ...                      ...   ...            ...
# 9515                 Kennedy    70         290.00
# 9516  Parque Central Bavaria   100         670.00
# 9517                Restrepo   383         900.00
# 9518                Engativa   183         335.00
# 9519                 Tintala    52         144.99
#
# [9520 rows x 3 columns]

# %%
media_preciomillon_barrios  =  inmuebles.groupby('Barrio')['Precio_Millon'].mean()

media_preciomillon_barrios
# Out:
# Barrio
# Alameda              580.00
# Alhambra             752.35
# Andes Norte          709.57
# Antonio Nariño       459.22
# Barrancas            314.13
#                       ...
# Villa Maria          402.85
# Villas De Granada    282.30
# Villemar             303.83
# Zona Franca          160.00
# Zona Noroccidental   620.81
# Name: Precio_Millon, Length: 149, dtype: float64

# %%
Precio_m2=media_preciomillon_barrios/media_areas_barrios
inmuebles["Precio_m2"]=Precio_m2[0]
Precio_m2.sample(10)
# Out:
# Barrio
# Suba             4.32
# El Retiro        7.12
# Pontevedra       4.67
# Fontibón         3.72
# Alhambra         3.95
# Villa Alsacia    4.14
# Los Rosales      8.21
# Florida Blanca   3.17
# Chico Norte Ii   5.99
# Galerias         4.45
# dtype: float64

# %% [markdown]
# # **Resultados DESAFIO 2**

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles["Valor_m2_Millon"]=inmuebles["Precio_Millon"]/inmuebles["Area"]
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %%
inmuebles.groupby("Barrio").mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# ...

# %%
datos_barrio=inmuebles.groupby("Barrio").sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
datos_barrio["Valor_m2_Barrio"]=datos_barrio["Precio_Millon"]/datos_barrio["Area"]
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98             5.98
# ...

# %%
dict(datos_barrio["Valor_m2_Barrio"])
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
m2_barrio=dict(datos_barrio["Valor_m2_Barrio"])

# %%
inmuebles["Valor_m2_Barrio"]=inmuebles["Barrio"]
inmuebles["Valor_m2_Barrio"]=inmuebles["Valor_m2_Barrio"].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# ...

# %% [markdown]
# # **AULA 3**

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tipo             9520 non-null   object
#  1   Descripcion      9520 non-null   object
#  2   Habitaciones     9520 non-null   int64
#  3   Banos            9520 non-null   int64
#  4   Area             9520 non-null   int64
#  5   Barrio           9520 non-null   object
#  6   UPZ              9478 non-null   object
#  7   Valor            9520 non-null   object
#  8   Moneda           9520 non-null   object
#  9   Precio           9520 non-null   object
#  10  Precio_Millon    9520 non-null   float64
#  11  Valor_m2_Millon  9520 non-null   float64
#  12  Valor_m2_Barrio  9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
#
#    Valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10

# %%
inmuebles["Barrio"].value_counts()[:10].index
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
top_barrios=inmuebles["Barrio"].value_counts()[:10].index

# %%
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98             5.98
# ...

# %%
datos_barrio.set_index("Barrio")
datos_barrio
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 0          0      0             Alameda             3      2      97
# 1          1      1            Alhambra            51     50    3237
# 2          2      2         Andes Norte            21     20     874
# 3          3      3      Antonio Nariño           207    120    7827
# 4          4      4           Barrancas            43     32    1053
# ..       ...    ...                 ...           ...    ...     ...
# 144      144    144         Villa Maria            61     48    2693
# 145      145    145   Villas De Granada            76     51    1905
# 146      146    146            Villemar            53     37    1384
# 147      147    147         Zona Franca             2      1      54
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# ...

# %%
datos_barrio.query("Barrio in @top_barrios")
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 5          5      5      Barrios Unidos          1525   1196   87799
# 10        10     10                Bosa          1743    789   34879
# 22        22     22            Cedritos          1458   1348   53711
# 24        24     24           Chapinero           892    913   81248
# 50        50     50            Engativa          1676   1077   59808
# 63        63     63             Kennedy          2151   1233   61475
# 125      125    125       Santa Barbara          1073   1162   54693
# 132      132    132                Suba          1497   1202   61615
# 138      138    138             Usaquén          3109   3044  148121
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# 5        259877.76          2070.61             2.96             2.96
# ...

# %%
datos_barrio.drop(["Valor_m2_BArrio"], axis=1)
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 0          0      0             Alameda             3      2      97
# 1          1      1            Alhambra            51     50    3237
# 2          2      2         Andes Norte            21     20     874
# 3          3      3      Antonio Nariño           207    120    7827
# 4          4      4           Barrancas            43     32    1053
# ..       ...    ...                 ...           ...    ...     ...
# 144      144    144         Villa Maria            61     48    2693
# 145      145    145   Villas De Granada            76     51    1905
# 146      146    146            Villemar            53     37    1384
# 147      147    147         Zona Franca             2      1      54
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 0           580.00             5.98             5.98
# ...

# %%
datos_barrio.reset_index(inplace=True)

# %%
datos_barrio.reset_index
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 0          0      0             Alameda             3      2      97
# 1          1      1            Alhambra            51     50    3237
# 2          2      2         Andes Norte            21     20     874
# 3          3      3      Antonio Nariño           207    120    7827
# 4          4      4           Barrancas            43     32    1053
# ..       ...    ...                 ...           ...    ...     ...
# 144      144    144         Villa Maria            61     48    2693
# 145      145    145   Villas De Granada            76     51    1905
# 146      146    146            Villemar            53     37    1384
# 147      147    147         Zona Franca             2      1      54
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# ...

# %%
datos_barrio
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 0          0      0             Alameda             3      2      97
# 1          1      1            Alhambra            51     50    3237
# 2          2      2         Andes Norte            21     20     874
# 3          3      3      Antonio Nariño           207    120    7827
# 4          4      4           Barrancas            43     32    1053
# ..       ...    ...                 ...           ...    ...     ...
# 144      144    144         Villa Maria            61     48    2693
# 145      145    145   Villas De Granada            76     51    1905
# 146      146    146            Villemar            53     37    1384
# 147      147    147         Zona Franca             2      1      54
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# ...

# %%
datos_barrio
# Out:
#      level_0  index              Barrio  Habitaciones  Banos    Area  \
# 0          0      0             Alameda             3      2      97
# 1          1      1            Alhambra            51     50    3237
# 2          2      2         Andes Norte            21     20     874
# 3          3      3      Antonio Nariño           207    120    7827
# 4          4      4           Barrancas            43     32    1053
# ..       ...    ...                 ...           ...    ...     ...
# 144      144    144         Villa Maria            61     48    2693
# 145      145    145   Villas De Granada            76     51    1905
# 146      146    146            Villemar            53     37    1384
# 147      147    147         Zona Franca             2      1      54
# 148      148    148  Zona Noroccidental          2778   2204  119084
#
#      Precio_Millon  Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# ...

# %%
datos_barrio.drop(["Valor_m2_BArrio"], axis=1)
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.drop(['index'], axis=1, inplace=True)

# %%
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_BArrio  Valor_m2_Barrio
# 0               5.98             5.98             5.98
# ...

# %%
datos_barrio.drop(['Valor_m2_BArrio'], axis=1, inplace=True)

# %%
datos_barrio
# Out:
#      index              Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0        0             Alameda             3      2      97         580.00
# 1        1            Alhambra            51     50    3237       12790.00
# 2        2         Andes Norte            21     20     874        4967.00
# 3        3      Antonio Nariño           207    120    7827       22042.65
# 4        4           Barrancas            43     32    1053        4712.00
# ..     ...                 ...           ...    ...     ...            ...
# 144    144         Villa Maria            61     48    2693        5237.00
# 145    145   Villas De Granada            76     51    1905        6210.62
# 146    146            Villemar            53     37    1384        5469.00
# 147    147         Zona Franca             2      1      54         160.00
# 148    148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# ...

# %%
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio.query("Barrio in @top_barrios")
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x="Barrio", y="Valor_m2_Barrio",data=datos_barrio.query("Barrio in @top_barrios"))

# %%
Barrios_unidos=(datos_barrio.Barrio=="Barrios Unidos")
Barrios_unidos
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Name: Barrio, Length: 149, dtype: bool

# %%
type(Barrios_unidos)
# Out:
# pandas.core.series.Series

# %%
barrios_unidos=datos_barrio[Barrios_unidos]
barrios_unidos
# Out:
#            Barrio  Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon  \
# 5  Barrios Unidos          1525   1196  87799      259877.76          2070.61
#
#    Valor_m2_Barrio
# 5             2.96

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x="Barrio", y="Valor_m2_Barrio",data=datos_barrio.query("Barrio in @top_barrios"))
ax.tick_params(axis="x", rotation=45)

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Valor_m2_Barrio",data=datos_barrio.query("Barrio in @top_barrios"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Valor_m2_Millon",data=inmuebles.query("Barrio in @top_barrios"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Valor_m2_Millon",data=inmuebles.query("Barrio in @top_barrios & Valor_m2_Millon<15"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Area",data=inmuebles.query("Barrio in @top_barrios"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Area",data=inmuebles.query("Barrio in @top_barrios & Area<500"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio", y="Precio_Millon",data=inmuebles.query("Barrio in @top_barrios & Precio_Millon<2000"))
ax.tick_params(axis="x", rotation=45)
plt.show()
